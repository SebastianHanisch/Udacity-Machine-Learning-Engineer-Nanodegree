# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 8
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 8:
# Image - Min Value: 8 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 8 Name: ship

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    max_val = np.max(x.flatten())
    min_val = np.min(x.flatten())
    normal_x = (x-min_val)/(max_val-min_val)
    return normal_x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
from sklearn.preprocessing import LabelBinarizer
lb=LabelBinarizer()
label_list = [i for i in range(10)]
lb.fit(label_list)

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    
    return lb.transform(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(dtype=tf.float32, shape=(None, image_shape[0], image_shape[1], image_shape[2]), name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(dtype=tf.int32, shape=(None, n_classes), name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(dtype=tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    n = conv_ksize[0]*conv_ksize[1]*x_tensor.get_shape().as_list()[3]
    weight = tf.Variable(tf.truncated_normal([conv_ksize[0], conv_ksize[1], x_tensor.get_shape().as_list()[3], conv_num_outputs], stddev=np.sqrt(2/n)))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    conv_layer = tf.nn.conv2d(x_tensor, weight, strides=[1, conv_strides[0], conv_strides[1], 1], padding='SAME')
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    conv_layer = tf.nn.max_pool(conv_layer, ksize=[1, pool_ksize[0], pool_ksize[1], 1], strides=[1, pool_strides[0], pool_strides[1], 1], padding='SAME')
    conv_layer = tf.nn.relu(conv_layer)
    return conv_layer 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    dim = np.prod(shape[1:])
    x_flattened = tf.reshape(x_tensor, [-1, dim]) 
    return x_flattened


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    n = x_tensor.get_shape().as_list()[1]
    weights = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1], num_outputs], stddev=np.sqrt(2/n)))
    bias = tf.Variable(tf.zeros(num_outputs))
    full_layer = tf.matmul(x_tensor, weights)
    full_layer = tf.add(full_layer, bias)
    full_layer = tf.nn.relu(full_layer)
    return full_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    n = x_tensor.get_shape().as_list()[1]
    weights = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1], num_outputs], stddev=np.sqrt(2/n)))
    bias = tf.Variable(tf.zeros(num_outputs))
    out_layer = tf.matmul(x_tensor, weights)
    out_layer = tf.add(out_layer, bias)
    return out_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv_1 = conv2d_maxpool(x, 16, (3,3),(1,1),(2,2),(2,2))
    conv_2 = conv2d_maxpool(conv_1, 32,  (3,3),(1,1),(2,2),(2,2))
    conv_3 = conv2d_maxpool(conv_2, 64, (3,3),(1,1),(2,2),(2,2))
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flattened = flatten(conv_3)
    
    #keep_prob = neural_net_keep_prob_input()
    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    full_layer_1 = tf.nn.dropout(fully_conn(flattened, 512), keep_prob)
    full_layer_2 = tf.nn.dropout(fully_conn(full_layer_1, 128), keep_prob)
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    out = output(full_layer_2,10)
    
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.0})
    print('Cost: ',loss)
    validation_accuracy = session.run(accuracy, feed_dict={x: valid_features, y: valid_labels, keep_prob: 1.0})
    print('Validation_accuracy: ', validation_accuracy)

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 50
batch_size = 256
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Cost:  2.11938
# Validation_accuracy:  0.2374
# Epoch  2, CIFAR-10 Batch 1:  Cost:  1.98188
# Validation_accuracy:  0.3688
# Epoch  3, CIFAR-10 Batch 1:  Cost:  1.77834
# Validation_accuracy:  0.4014
# Epoch  4, CIFAR-10 Batch 1:  Cost:  1.5559
# Validation_accuracy:  0.4446
# Epoch  5, CIFAR-10 Batch 1:  Cost:  1.40473
# Validation_accuracy:  0.4722
# Epoch  6, CIFAR-10 Batch 1:  Cost:  1.23739
# Validation_accuracy:  0.4884
# Epoch  7, CIFAR-10 Batch 1:  Cost:  1.06202
# Validation_accuracy:  0.508
# Epoch  8, CIFAR-10 Batch 1:  Cost:  0.95736
# Validation_accuracy:  0.5262
# Epoch  9, CIFAR-10 Batch 1:  Cost:  0.831788
# Validation_accuracy:  0.5288
# Epoch 10, CIFAR-10 Batch 1:  Cost:  0.739351
# Validation_accuracy:  0.5432
# Epoch 11, CIFAR-10 Batch 1:  Cost:  0.621033
# Validation_accuracy:  0.5542
# Epoch 12, CIFAR-10 Batch 1:  Cost:  0.56027
# Validation_accuracy:  0.5678
# Epoch 13, CIFAR-10 Batch 1:  Cost:  0.489247
# Validation_accuracy:  0.5634
# Epoch 14, CIFAR-10 Batch 1:  Cost:  0.403803
# Validation_accuracy:  0.5722
# Epoch 15, CIFAR-10 Batch 1:  Cost:  0.344741
# Validation_accuracy:  0.5814
# Epoch 16, CIFAR-10 Batch 1:  Cost:  0.316499
# Validation_accuracy:  0.5848
# Epoch 17, CIFAR-10 Batch 1:  Cost:  0.264026
# Validation_accuracy:  0.5942
# Epoch 18, CIFAR-10 Batch 1:  Cost:  0.234619
# Validation_accuracy:  0.5948
# Epoch 19, CIFAR-10 Batch 1:  Cost:  0.24922
# Validation_accuracy:  0.5852
# Epoch 20, CIFAR-10 Batch 1:  Cost:  0.165588
# Validation_accuracy:  0.5958
# Epoch 21, CIFAR-10 Batch 1:  Cost:  0.145599
# Validation_accuracy:  0.6058
# Epoch 22, CIFAR-10 Batch 1:  Cost:  0.132997
# Validation_accuracy:  0.5878
# Epoch 23, CIFAR-10 Batch 1:  Cost:  0.115685
# Validation_accuracy:  0.5858
# Epoch 24, CIFAR-10 Batch 1:  Cost:  0.0770564
# Validation_accuracy:  0.5992
# Epoch 25, CIFAR-10 Batch 1:  Cost:  0.0714042
# Validation_accuracy:  0.5994
# Epoch 26, CIFAR-10 Batch 1:  Cost:  0.0729926
# Validation_accuracy:  0.5894
# Epoch 27, CIFAR-10 Batch 1:  Cost:  0.0591772
# Validation_accuracy:  0.6164
# Epoch 28, CIFAR-10 Batch 1:  Cost:  0.0447371
# Validation_accuracy:  0.6002
# Epoch 29, CIFAR-10 Batch 1:  Cost:  0.0500195
# Validation_accuracy:  0.5858
# Epoch 30, CIFAR-10 Batch 1:  Cost:  0.0275476
# Validation_accuracy:  0.5914
# Epoch 31, CIFAR-10 Batch 1:  Cost:  0.0441286
# Validation_accuracy:  0.5674
# Epoch 32, CIFAR-10 Batch 1:  Cost:  0.0312992
# Validation_accuracy:  0.5808
# Epoch 33, CIFAR-10 Batch 1:  Cost:  0.0248931
# Validation_accuracy:  0.5934
# Epoch 34, CIFAR-10 Batch 1:  Cost:  0.0315372
# Validation_accuracy:  0.5742
# Epoch 35, CIFAR-10 Batch 1:  Cost:  0.0292024
# Validation_accuracy:  0.5778
# Epoch 36, CIFAR-10 Batch 1:  Cost:  0.023275
# Validation_accuracy:  0.5966
# Epoch 37, CIFAR-10 Batch 1:  Cost:  0.017623
# Validation_accuracy:  0.6024
# Epoch 38, CIFAR-10 Batch 1:  Cost:  0.0109281
# Validation_accuracy:  0.6014
# Epoch 39, CIFAR-10 Batch 1:  Cost:  0.00823976
# Validation_accuracy:  0.5966
# Epoch 40, CIFAR-10 Batch 1:  Cost:  0.00652357
# Validation_accuracy:  0.605
# Epoch 41, CIFAR-10 Batch 1:  Cost:  0.00561543
# Validation_accuracy:  0.602
# Epoch 42, CIFAR-10 Batch 1:  Cost:  0.00679004
# Validation_accuracy:  0.5942
# Epoch 43, CIFAR-10 Batch 1:  Cost:  0.00613146
# Validation_accuracy:  0.6054
# Epoch 44, CIFAR-10 Batch 1:  Cost:  0.00343981
# Validation_accuracy:  0.5964
# Epoch 45, CIFAR-10 Batch 1:  Cost:  0.00396193
# Validation_accuracy:  0.5994
# Epoch 46, CIFAR-10 Batch 1:  Cost:  0.0025034
# Validation_accuracy:  0.5974
# Epoch 47, CIFAR-10 Batch 1:  Cost:  0.00237018
# Validation_accuracy:  0.6036
# Epoch 48, CIFAR-10 Batch 1:  Cost:  0.00244345
# Validation_accuracy:  0.59
# Epoch 49, CIFAR-10 Batch 1:  Cost:  0.00428961
# Validation_accuracy:  0.5968
# Epoch 50, CIFAR-10 Batch 1:  Cost:  0.00363723
# Validation_accuracy:  0.594

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Cost:  2.10132
# Validation_accuracy:  0.25
# Epoch  1, CIFAR-10 Batch 2:  Cost:  1.83788
# Validation_accuracy:  0.3836
# Epoch  1, CIFAR-10 Batch 3:  Cost:  1.48024
# Validation_accuracy:  0.3712
# Epoch  1, CIFAR-10 Batch 4:  Cost:  1.51252
# Validation_accuracy:  0.46
# Epoch  1, CIFAR-10 Batch 5:  Cost:  1.49502
# Validation_accuracy:  0.487
# Epoch  2, CIFAR-10 Batch 1:  Cost:  1.56533
# Validation_accuracy:  0.4836
# Epoch  2, CIFAR-10 Batch 2:  Cost:  1.34946
# Validation_accuracy:  0.4834
# Epoch  2, CIFAR-10 Batch 3:  Cost:  1.07673
# Validation_accuracy:  0.5292
# Epoch  2, CIFAR-10 Batch 4:  Cost:  1.17443
# Validation_accuracy:  0.5356
# Epoch  2, CIFAR-10 Batch 5:  Cost:  1.14389
# Validation_accuracy:  0.554
# Epoch  3, CIFAR-10 Batch 1:  Cost:  1.20395
# Validation_accuracy:  0.5518
# Epoch  3, CIFAR-10 Batch 2:  Cost:  0.98399
# Validation_accuracy:  0.5662
# Epoch  3, CIFAR-10 Batch 3:  Cost:  0.816482
# Validation_accuracy:  0.5828
# Epoch  3, CIFAR-10 Batch 4:  Cost:  0.956365
# Validation_accuracy:  0.5906
# Epoch  3, CIFAR-10 Batch 5:  Cost:  0.885754
# Validation_accuracy:  0.6064
# Epoch  4, CIFAR-10 Batch 1:  Cost:  0.915627
# Validation_accuracy:  0.6146
# Epoch  4, CIFAR-10 Batch 2:  Cost:  0.744596
# Validation_accuracy:  0.602
# Epoch  4, CIFAR-10 Batch 3:  Cost:  0.733389
# Validation_accuracy:  0.6
# Epoch  4, CIFAR-10 Batch 4:  Cost:  0.689302
# Validation_accuracy:  0.6302
# Epoch  4, CIFAR-10 Batch 5:  Cost:  0.72634
# Validation_accuracy:  0.6252
# Epoch  5, CIFAR-10 Batch 1:  Cost:  0.809647
# Validation_accuracy:  0.5954
# Epoch  5, CIFAR-10 Batch 2:  Cost:  0.59372
# Validation_accuracy:  0.6332
# Epoch  5, CIFAR-10 Batch 3:  Cost:  0.576393
# Validation_accuracy:  0.6304
# Epoch  5, CIFAR-10 Batch 4:  Cost:  0.553156
# Validation_accuracy:  0.6404
# Epoch  5, CIFAR-10 Batch 5:  Cost:  0.544323
# Validation_accuracy:  0.6558
# Epoch  6, CIFAR-10 Batch 1:  Cost:  0.659793
# Validation_accuracy:  0.6478
# Epoch  6, CIFAR-10 Batch 2:  Cost:  0.473595
# Validation_accuracy:  0.658
# Epoch  6, CIFAR-10 Batch 3:  Cost:  0.470263
# Validation_accuracy:  0.6454
# Epoch  6, CIFAR-10 Batch 4:  Cost:  0.440847
# Validation_accuracy:  0.655
# Epoch  6, CIFAR-10 Batch 5:  Cost:  0.450875
# Validation_accuracy:  0.6658
# Epoch  7, CIFAR-10 Batch 1:  Cost:  0.612297
# Validation_accuracy:  0.6568
# Epoch  7, CIFAR-10 Batch 2:  Cost:  0.407101
# Validation_accuracy:  0.6574
# Epoch  7, CIFAR-10 Batch 3:  Cost:  0.376459
# Validation_accuracy:  0.6672
# Epoch  7, CIFAR-10 Batch 4:  Cost:  0.366183
# Validation_accuracy:  0.6834
# Epoch  7, CIFAR-10 Batch 5:  Cost:  0.336198
# Validation_accuracy:  0.6514
# Epoch  8, CIFAR-10 Batch 1:  Cost:  0.495318
# Validation_accuracy:  0.647
# Epoch  8, CIFAR-10 Batch 2:  Cost:  0.316374
# Validation_accuracy:  0.6794
# Epoch  8, CIFAR-10 Batch 3:  Cost:  0.300734
# Validation_accuracy:  0.6794
# Epoch  8, CIFAR-10 Batch 4:  Cost:  0.288261
# Validation_accuracy:  0.6808
# Epoch  8, CIFAR-10 Batch 5:  Cost:  0.318358
# Validation_accuracy:  0.667
# Epoch  9, CIFAR-10 Batch 1:  Cost:  0.377537
# Validation_accuracy:  0.673
# Epoch  9, CIFAR-10 Batch 2:  Cost:  0.279448
# Validation_accuracy:  0.677
# Epoch  9, CIFAR-10 Batch 3:  Cost:  0.256618
# Validation_accuracy:  0.6758
# Epoch  9, CIFAR-10 Batch 4:  Cost:  0.230493
# Validation_accuracy:  0.6918
# Epoch  9, CIFAR-10 Batch 5:  Cost:  0.205463
# Validation_accuracy:  0.6834
# Epoch 10, CIFAR-10 Batch 1:  Cost:  0.28916
# Validation_accuracy:  0.6968
# Epoch 10, CIFAR-10 Batch 2:  Cost:  0.230835
# Validation_accuracy:  0.677
# Epoch 10, CIFAR-10 Batch 3:  Cost:  0.217498
# Validation_accuracy:  0.6872
# Epoch 10, CIFAR-10 Batch 4:  Cost:  0.203789
# Validation_accuracy:  0.6918
# Epoch 10, CIFAR-10 Batch 5:  Cost:  0.151557
# Validation_accuracy:  0.6914
# Epoch 11, CIFAR-10 Batch 1:  Cost:  0.29876
# Validation_accuracy:  0.6896
# Epoch 11, CIFAR-10 Batch 2:  Cost:  0.214328
# Validation_accuracy:  0.6902
# Epoch 11, CIFAR-10 Batch 3:  Cost:  0.229444
# Validation_accuracy:  0.6736
# Epoch 11, CIFAR-10 Batch 4:  Cost:  0.217196
# Validation_accuracy:  0.6912
# Epoch 11, CIFAR-10 Batch 5:  Cost:  0.145006
# Validation_accuracy:  0.6816
# Epoch 12, CIFAR-10 Batch 1:  Cost:  0.217401
# Validation_accuracy:  0.692
# Epoch 12, CIFAR-10 Batch 2:  Cost:  0.180655
# Validation_accuracy:  0.6962
# Epoch 12, CIFAR-10 Batch 3:  Cost:  0.168836
# Validation_accuracy:  0.6888
# Epoch 12, CIFAR-10 Batch 4:  Cost:  0.191132
# Validation_accuracy:  0.6942
# Epoch 12, CIFAR-10 Batch 5:  Cost:  0.0948244
# Validation_accuracy:  0.6932
# Epoch 13, CIFAR-10 Batch 1:  Cost:  0.164728
# Validation_accuracy:  0.7096
# Epoch 13, CIFAR-10 Batch 2:  Cost:  0.152725
# Validation_accuracy:  0.701
# Epoch 13, CIFAR-10 Batch 3:  Cost:  0.145587
# Validation_accuracy:  0.689
# Epoch 13, CIFAR-10 Batch 4:  Cost:  0.133985
# Validation_accuracy:  0.7022
# Epoch 13, CIFAR-10 Batch 5:  Cost:  0.103356
# Validation_accuracy:  0.6966
# Epoch 14, CIFAR-10 Batch 1:  Cost:  0.150838
# Validation_accuracy:  0.709
# Epoch 14, CIFAR-10 Batch 2:  Cost:  0.126391
# Validation_accuracy:  0.7092
# Epoch 14, CIFAR-10 Batch 3:  Cost:  0.0996169
# Validation_accuracy:  0.6984
# Epoch 14, CIFAR-10 Batch 4:  Cost:  0.127086
# Validation_accuracy:  0.694
# Epoch 14, CIFAR-10 Batch 5:  Cost:  0.0996228
# Validation_accuracy:  0.7024
# Epoch 15, CIFAR-10 Batch 1:  Cost:  0.143578
# Validation_accuracy:  0.7054
# Epoch 15, CIFAR-10 Batch 2:  Cost:  0.138708
# Validation_accuracy:  0.7094
# Epoch 15, CIFAR-10 Batch 3:  Cost:  0.0767666
# Validation_accuracy:  0.702
# Epoch 15, CIFAR-10 Batch 4:  Cost:  0.111271
# Validation_accuracy:  0.6912
# Epoch 15, CIFAR-10 Batch 5:  Cost:  0.0878789
# Validation_accuracy:  0.683
# Epoch 16, CIFAR-10 Batch 1:  Cost:  0.139588
# Validation_accuracy:  0.6986
# Epoch 16, CIFAR-10 Batch 2:  Cost:  0.110547
# Validation_accuracy:  0.7062
# Epoch 16, CIFAR-10 Batch 3:  Cost:  0.0804567
# Validation_accuracy:  0.7032
# Epoch 16, CIFAR-10 Batch 4:  Cost:  0.0829518
# Validation_accuracy:  0.7016
# Epoch 16, CIFAR-10 Batch 5:  Cost:  0.0584825
# Validation_accuracy:  0.6904
# Epoch 17, CIFAR-10 Batch 1:  Cost:  0.126772
# Validation_accuracy:  0.7002
# Epoch 17, CIFAR-10 Batch 2:  Cost:  0.0742527
# Validation_accuracy:  0.7104
# Epoch 17, CIFAR-10 Batch 3:  Cost:  0.081459
# Validation_accuracy:  0.7068
# Epoch 17, CIFAR-10 Batch 4:  Cost:  0.0825428
# Validation_accuracy:  0.7128
# Epoch 17, CIFAR-10 Batch 5:  Cost:  0.0367797
# Validation_accuracy:  0.707
# Epoch 18, CIFAR-10 Batch 1:  Cost:  0.113322
# Validation_accuracy:  0.7022
# Epoch 18, CIFAR-10 Batch 2:  Cost:  0.061403
# Validation_accuracy:  0.703
# Epoch 18, CIFAR-10 Batch 3:  Cost:  0.055662
# Validation_accuracy:  0.7158
# Epoch 18, CIFAR-10 Batch 4:  Cost:  0.0669533
# Validation_accuracy:  0.7194
# Epoch 18, CIFAR-10 Batch 5:  Cost:  0.0374337
# Validation_accuracy:  0.7076
# Epoch 19, CIFAR-10 Batch 1:  Cost:  0.107422
# Validation_accuracy:  0.6992
# Epoch 19, CIFAR-10 Batch 2:  Cost:  0.0673557
# Validation_accuracy:  0.6928
# Epoch 19, CIFAR-10 Batch 3:  Cost:  0.048306
# Validation_accuracy:  0.7152
# Epoch 19, CIFAR-10 Batch 4:  Cost:  0.0553185
# Validation_accuracy:  0.716
# Epoch 19, CIFAR-10 Batch 5:  Cost:  0.0290058
# Validation_accuracy:  0.7052
# Epoch 20, CIFAR-10 Batch 1:  Cost:  0.0829793
# Validation_accuracy:  0.7012
# Epoch 20, CIFAR-10 Batch 2:  Cost:  0.0653464
# Validation_accuracy:  0.6948
# Epoch 20, CIFAR-10 Batch 3:  Cost:  0.0397727
# Validation_accuracy:  0.7106
# Epoch 20, CIFAR-10 Batch 4:  Cost:  0.0541697
# Validation_accuracy:  0.7118
# Epoch 20, CIFAR-10 Batch 5:  Cost:  0.0218281
# Validation_accuracy:  0.7142
# Epoch 21, CIFAR-10 Batch 1:  Cost:  0.0796587
# Validation_accuracy:  0.703
# Epoch 21, CIFAR-10 Batch 2:  Cost:  0.0610114
# Validation_accuracy:  0.6848
# Epoch 21, CIFAR-10 Batch 3:  Cost:  0.0559852
# Validation_accuracy:  0.7142
# Epoch 21, CIFAR-10 Batch 4:  Cost:  0.0496094
# Validation_accuracy:  0.712
# Epoch 21, CIFAR-10 Batch 5:  Cost:  0.0230986
# Validation_accuracy:  0.7094
# Epoch 22, CIFAR-10 Batch 1:  Cost:  0.0746683
# Validation_accuracy:  0.6982
# Epoch 22, CIFAR-10 Batch 2:  Cost:  0.0507394
# Validation_accuracy:  0.7054
# Epoch 22, CIFAR-10 Batch 3:  Cost:  0.0459474
# Validation_accuracy:  0.7156
# Epoch 22, CIFAR-10 Batch 4:  Cost:  0.046553
# Validation_accuracy:  0.7126
# Epoch 22, CIFAR-10 Batch 5:  Cost:  0.0236488
# Validation_accuracy:  0.7168
# Epoch 23, CIFAR-10 Batch 1:  Cost:  0.0701199
# Validation_accuracy:  0.6912
# Epoch 23, CIFAR-10 Batch 2:  Cost:  0.0572201
# Validation_accuracy:  0.704
# Epoch 23, CIFAR-10 Batch 3:  Cost:  0.0468457
# Validation_accuracy:  0.7062
# Epoch 23, CIFAR-10 Batch 4:  Cost:  0.0439039
# Validation_accuracy:  0.7164
# Epoch 23, CIFAR-10 Batch 5:  Cost:  0.021243
# Validation_accuracy:  0.7154
# Epoch 24, CIFAR-10 Batch 1:  Cost:  0.0580618
# Validation_accuracy:  0.6938
# Epoch 24, CIFAR-10 Batch 2:  Cost:  0.0532314
# Validation_accuracy:  0.711
# Epoch 24, CIFAR-10 Batch 3:  Cost:  0.0433392
# Validation_accuracy:  0.7074
# Epoch 24, CIFAR-10 Batch 4:  Cost:  0.0337893
# Validation_accuracy:  0.7156
# Epoch 24, CIFAR-10 Batch 5:  Cost:  0.0198062
# Validation_accuracy:  0.715
# Epoch 25, CIFAR-10 Batch 1:  Cost:  0.0434296
# Validation_accuracy:  0.7086
# Epoch 25, CIFAR-10 Batch 2:  Cost:  0.0414562
# Validation_accuracy:  0.716
# Epoch 25, CIFAR-10 Batch 3:  Cost:  0.0212338
# Validation_accuracy:  0.7172
# Epoch 25, CIFAR-10 Batch 4:  Cost:  0.0363175
# Validation_accuracy:  0.7094
# Epoch 25, CIFAR-10 Batch 5:  Cost:  0.0181721
# Validation_accuracy:  0.7066
# Epoch 26, CIFAR-10 Batch 1:  Cost:  0.0510635
# Validation_accuracy:  0.6894
# Epoch 26, CIFAR-10 Batch 2:  Cost:  0.0252649
# Validation_accuracy:  0.7104
# Epoch 26, CIFAR-10 Batch 3:  Cost:  0.0167221
# Validation_accuracy:  0.7162
# Epoch 26, CIFAR-10 Batch 4:  Cost:  0.0343752
# Validation_accuracy:  0.7178
# Epoch 26, CIFAR-10 Batch 5:  Cost:  0.0134986
# Validation_accuracy:  0.7204
# Epoch 27, CIFAR-10 Batch 1:  Cost:  0.0440273
# Validation_accuracy:  0.7194
# Epoch 27, CIFAR-10 Batch 2:  Cost:  0.0374119
# Validation_accuracy:  0.7
# Epoch 27, CIFAR-10 Batch 3:  Cost:  0.0177826
# Validation_accuracy:  0.713
# Epoch 27, CIFAR-10 Batch 4:  Cost:  0.0277941
# Validation_accuracy:  0.7096
# Epoch 27, CIFAR-10 Batch 5:  Cost:  0.0055926
# Validation_accuracy:  0.7222
# Epoch 28, CIFAR-10 Batch 1:  Cost:  0.0408921
# Validation_accuracy:  0.7146
# Epoch 28, CIFAR-10 Batch 2:  Cost:  0.0462937
# Validation_accuracy:  0.689
# Epoch 28, CIFAR-10 Batch 3:  Cost:  0.0193076
# Validation_accuracy:  0.7114
# Epoch 28, CIFAR-10 Batch 4:  Cost:  0.0254558
# Validation_accuracy:  0.706
# Epoch 28, CIFAR-10 Batch 5:  Cost:  0.012465
# Validation_accuracy:  0.7162
# Epoch 29, CIFAR-10 Batch 1:  Cost:  0.0394871
# Validation_accuracy:  0.712
# Epoch 29, CIFAR-10 Batch 2:  Cost:  0.0181666
# Validation_accuracy:  0.7186
# Epoch 29, CIFAR-10 Batch 3:  Cost:  0.0163547
# Validation_accuracy:  0.7176
# Epoch 29, CIFAR-10 Batch 4:  Cost:  0.0178557
# Validation_accuracy:  0.7126
# Epoch 29, CIFAR-10 Batch 5:  Cost:  0.0172517
# Validation_accuracy:  0.7166
# Epoch 30, CIFAR-10 Batch 1:  Cost:  0.0331689
# Validation_accuracy:  0.7022
# Epoch 30, CIFAR-10 Batch 2:  Cost:  0.0181167
# Validation_accuracy:  0.7138
# Epoch 30, CIFAR-10 Batch 3:  Cost:  0.0236776
# Validation_accuracy:  0.6982
# Epoch 30, CIFAR-10 Batch 4:  Cost:  0.0164001
# Validation_accuracy:  0.7144
# Epoch 30, CIFAR-10 Batch 5:  Cost:  0.00982258
# Validation_accuracy:  0.7224
# Epoch 31, CIFAR-10 Batch 1:  Cost:  0.0215361
# Validation_accuracy:  0.7076
# Epoch 31, CIFAR-10 Batch 2:  Cost:  0.010717
# Validation_accuracy:  0.7092
# Epoch 31, CIFAR-10 Batch 3:  Cost:  0.0136264
# Validation_accuracy:  0.6978
# Epoch 31, CIFAR-10 Batch 4:  Cost:  0.0135731
# Validation_accuracy:  0.713
# Epoch 31, CIFAR-10 Batch 5:  Cost:  0.010959
# Validation_accuracy:  0.717
# Epoch 32, CIFAR-10 Batch 1:  Cost:  0.0186888
# Validation_accuracy:  0.7014
# Epoch 32, CIFAR-10 Batch 2:  Cost:  0.00791042
# Validation_accuracy:  0.716
# Epoch 32, CIFAR-10 Batch 3:  Cost:  0.00912198
# Validation_accuracy:  0.709
# Epoch 32, CIFAR-10 Batch 4:  Cost:  0.0215622
# Validation_accuracy:  0.7076
# Epoch 32, CIFAR-10 Batch 5:  Cost:  0.00951662
# Validation_accuracy:  0.7156
# Epoch 33, CIFAR-10 Batch 1:  Cost:  0.0225268
# Validation_accuracy:  0.6998
# Epoch 33, CIFAR-10 Batch 2:  Cost:  0.00977683
# Validation_accuracy:  0.7198
# Epoch 33, CIFAR-10 Batch 3:  Cost:  0.0135191
# Validation_accuracy:  0.6978
# Epoch 33, CIFAR-10 Batch 4:  Cost:  0.0178119
# Validation_accuracy:  0.7114
# Epoch 33, CIFAR-10 Batch 5:  Cost:  0.014827
# Validation_accuracy:  0.6984
# Epoch 34, CIFAR-10 Batch 1:  Cost:  0.0275945
# Validation_accuracy:  0.7052
# Epoch 34, CIFAR-10 Batch 2:  Cost:  0.00763524
# Validation_accuracy:  0.7148
# Epoch 34, CIFAR-10 Batch 3:  Cost:  0.0138035
# Validation_accuracy:  0.704
# Epoch 34, CIFAR-10 Batch 4:  Cost:  0.014649
# Validation_accuracy:  0.714
# Epoch 34, CIFAR-10 Batch 5:  Cost:  0.00903498
# Validation_accuracy:  0.7134
# Epoch 35, CIFAR-10 Batch 1:  Cost:  0.014226
# Validation_accuracy:  0.6976
# Epoch 35, CIFAR-10 Batch 2:  Cost:  0.00607042
# Validation_accuracy:  0.7202
# Epoch 35, CIFAR-10 Batch 3:  Cost:  0.00644907
# Validation_accuracy:  0.7132
# Epoch 35, CIFAR-10 Batch 4:  Cost:  0.0124527
# Validation_accuracy:  0.7198
# Epoch 35, CIFAR-10 Batch 5:  Cost:  0.00604211
# Validation_accuracy:  0.7226
# Epoch 36, CIFAR-10 Batch 1:  Cost:  0.0221558
# Validation_accuracy:  0.6976
# Epoch 36, CIFAR-10 Batch 2:  Cost:  0.00644401
# Validation_accuracy:  0.7188
# Epoch 36, CIFAR-10 Batch 3:  Cost:  0.00523581
# Validation_accuracy:  0.7138
# Epoch 36, CIFAR-10 Batch 4:  Cost:  0.0107073
# Validation_accuracy:  0.7084
# Epoch 36, CIFAR-10 Batch 5:  Cost:  0.00397032
# Validation_accuracy:  0.708
# Epoch 37, CIFAR-10 Batch 1:  Cost:  0.0103347
# Validation_accuracy:  0.7098
# Epoch 37, CIFAR-10 Batch 2:  Cost:  0.00795153
# Validation_accuracy:  0.7144
# Epoch 37, CIFAR-10 Batch 3:  Cost:  0.0060117
# Validation_accuracy:  0.7192
# Epoch 37, CIFAR-10 Batch 4:  Cost:  0.00847053
# Validation_accuracy:  0.722
# Epoch 37, CIFAR-10 Batch 5:  Cost:  0.0073403
# Validation_accuracy:  0.7144
# Epoch 38, CIFAR-10 Batch 1:  Cost:  0.0152959
# Validation_accuracy:  0.7014
# Epoch 38, CIFAR-10 Batch 2:  Cost:  0.0158184
# Validation_accuracy:  0.702
# Epoch 38, CIFAR-10 Batch 3:  Cost:  0.00540924
# Validation_accuracy:  0.7174
# Epoch 38, CIFAR-10 Batch 4:  Cost:  0.0113351
# Validation_accuracy:  0.7154
# Epoch 38, CIFAR-10 Batch 5:  Cost:  0.00597726
# Validation_accuracy:  0.7046
# Epoch 39, CIFAR-10 Batch 1:  Cost:  0.00782878
# Validation_accuracy:  0.7182
# Epoch 39, CIFAR-10 Batch 2:  Cost:  0.00418424
# Validation_accuracy:  0.7186
# Epoch 39, CIFAR-10 Batch 3:  Cost:  0.00578309
# Validation_accuracy:  0.72
# Epoch 39, CIFAR-10 Batch 4:  Cost:  0.00585005
# Validation_accuracy:  0.7168
# Epoch 39, CIFAR-10 Batch 5:  Cost:  0.00401212
# Validation_accuracy:  0.7156
# Epoch 40, CIFAR-10 Batch 1:  Cost:  0.00939255
# Validation_accuracy:  0.718
# Epoch 40, CIFAR-10 Batch 2:  Cost:  0.00492211
# Validation_accuracy:  0.7166
# Epoch 40, CIFAR-10 Batch 3:  Cost:  0.00515122
# Validation_accuracy:  0.7146
# Epoch 40, CIFAR-10 Batch 4:  Cost:  0.00824963
# Validation_accuracy:  0.7086
# Epoch 40, CIFAR-10 Batch 5:  Cost:  0.00541159
# Validation_accuracy:  0.7064
# Epoch 41, CIFAR-10 Batch 1:  Cost:  0.00886062
# Validation_accuracy:  0.7136
# Epoch 41, CIFAR-10 Batch 2:  Cost:  0.00379189
# Validation_accuracy:  0.7108
# Epoch 41, CIFAR-10 Batch 3:  Cost:  0.00348442
# Validation_accuracy:  0.7172
# Epoch 41, CIFAR-10 Batch 4:  Cost:  0.0110156
# Validation_accuracy:  0.717
# Epoch 41, CIFAR-10 Batch 5:  Cost:  0.00161337
# Validation_accuracy:  0.7286
# Epoch 42, CIFAR-10 Batch 1:  Cost:  0.00616767
# Validation_accuracy:  0.7188
# Epoch 42, CIFAR-10 Batch 2:  Cost:  0.00457556
# Validation_accuracy:  0.7208
# Epoch 42, CIFAR-10 Batch 3:  Cost:  0.00457648
# Validation_accuracy:  0.7098
# Epoch 42, CIFAR-10 Batch 4:  Cost:  0.00500769
# Validation_accuracy:  0.7182
# Epoch 42, CIFAR-10 Batch 5:  Cost:  0.00272643
# Validation_accuracy:  0.7192
# Epoch 43, CIFAR-10 Batch 1:  Cost:  0.00787775
# Validation_accuracy:  0.7184
# Epoch 43, CIFAR-10 Batch 2:  Cost:  0.00594838
# Validation_accuracy:  0.7198
# Epoch 43, CIFAR-10 Batch 3:  Cost:  0.00416629
# Validation_accuracy:  0.7194
# Epoch 43, CIFAR-10 Batch 4:  Cost:  0.0045619
# Validation_accuracy:  0.7228
# Epoch 43, CIFAR-10 Batch 5:  Cost:  0.00145409
# Validation_accuracy:  0.7272
# Epoch 44, CIFAR-10 Batch 1:  Cost:  0.00353824
# Validation_accuracy:  0.7262
# Epoch 44, CIFAR-10 Batch 2:  Cost:  0.0046253
# Validation_accuracy:  0.725
# Epoch 44, CIFAR-10 Batch 3:  Cost:  0.00435844
# Validation_accuracy:  0.7088
# Epoch 44, CIFAR-10 Batch 4:  Cost:  0.00667346
# Validation_accuracy:  0.7148
# Epoch 44, CIFAR-10 Batch 5:  Cost:  0.00191879
# Validation_accuracy:  0.717
# Epoch 45, CIFAR-10 Batch 1:  Cost:  0.00692013
# Validation_accuracy:  0.7148
# Epoch 45, CIFAR-10 Batch 2:  Cost:  0.00299227
# Validation_accuracy:  0.7196
# Epoch 45, CIFAR-10 Batch 3:  Cost:  0.00259312
# Validation_accuracy:  0.7138
# Epoch 45, CIFAR-10 Batch 4:  Cost:  0.00388113
# Validation_accuracy:  0.7084
# Epoch 45, CIFAR-10 Batch 5:  Cost:  0.00177529
# Validation_accuracy:  0.7226
# Epoch 46, CIFAR-10 Batch 1:  Cost:  0.006186
# Validation_accuracy:  0.719
# Epoch 46, CIFAR-10 Batch 2:  Cost:  0.00534243
# Validation_accuracy:  0.7212
# Epoch 46, CIFAR-10 Batch 3:  Cost:  0.00154991
# Validation_accuracy:  0.7136
# Epoch 46, CIFAR-10 Batch 4:  Cost:  0.00486646
# Validation_accuracy:  0.7172
# Epoch 46, CIFAR-10 Batch 5:  Cost:  0.00258639
# Validation_accuracy:  0.7256
# Epoch 47, CIFAR-10 Batch 1:  Cost:  0.00508213
# Validation_accuracy:  0.7182
# Epoch 47, CIFAR-10 Batch 2:  Cost:  0.00222791
# Validation_accuracy:  0.72
# Epoch 47, CIFAR-10 Batch 3:  Cost:  0.00166204
# Validation_accuracy:  0.7136
# Epoch 47, CIFAR-10 Batch 4:  Cost:  0.00313085
# Validation_accuracy:  0.7146
# Epoch 47, CIFAR-10 Batch 5:  Cost:  0.0022254
# Validation_accuracy:  0.7294
# Epoch 48, CIFAR-10 Batch 1:  Cost:  0.00717673
# Validation_accuracy:  0.7178
# Epoch 48, CIFAR-10 Batch 2:  Cost:  0.00521295
# Validation_accuracy:  0.724
# Epoch 48, CIFAR-10 Batch 3:  Cost:  0.00112534
# Validation_accuracy:  0.7178
# Epoch 48, CIFAR-10 Batch 4:  Cost:  0.00202234
# Validation_accuracy:  0.7138
# Epoch 48, CIFAR-10 Batch 5:  Cost:  0.00289686
# Validation_accuracy:  0.7182
# Epoch 49, CIFAR-10 Batch 1:  Cost:  0.00651918
# Validation_accuracy:  0.7166
# Epoch 49, CIFAR-10 Batch 2:  Cost:  0.00121453
# Validation_accuracy:  0.7176
# Epoch 49, CIFAR-10 Batch 3:  Cost:  0.00149932
# Validation_accuracy:  0.7134
# Epoch 49, CIFAR-10 Batch 4:  Cost:  0.00237257
# Validation_accuracy:  0.7148
# Epoch 49, CIFAR-10 Batch 5:  Cost:  0.00562608
# Validation_accuracy:  0.7218
# Epoch 50, CIFAR-10 Batch 1:  Cost:  0.00895642
# Validation_accuracy:  0.7064
# Epoch 50, CIFAR-10 Batch 2:  Cost:  0.000882828
# Validation_accuracy:  0.7168
# Epoch 50, CIFAR-10 Batch 3:  Cost:  0.00119645
# Validation_accuracy:  0.714
# Epoch 50, CIFAR-10 Batch 4:  Cost:  0.00248248
# Validation_accuracy:  0.7134
# Epoch 50, CIFAR-10 Batch 5:  Cost:  0.00149907
# Validation_accuracy:  0.7206

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.71005859375

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
